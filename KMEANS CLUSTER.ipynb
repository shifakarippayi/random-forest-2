# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/kmeansData (1).csv')
df
# Out:
#    1.42  0.67
# 0  2.05  1.70
# 1  3.20  3.52
# 2  3.70  0.15
# 3  4.70  1.45
# 4  6.17  2.67
# 5  7.80  3.70
# 6  8.74  4.52
# 7  9.25  2.15
# 8  9.70  3.45

# %%
df.head()
# Out:
#    1.42  0.67
# 0  2.05  1.70
# 1  3.20  3.52
# 2  3.70  0.15
# 3  4.70  1.45
# 4  6.17  2.67

# %%
df.shape
# Out:
# (9, 2)

# %%
from sklearn.cluster import KMeans
kmeans= KMeans(n_clusters=3,init='k-means++',random_state=0)
kmeans.fit(df)
kmeans.inertia_
# Out:
# 14.630741666666667

# %%
from sklearn.cluster import KMeans
wcss= []
for i in range(1,10):
    kmeans1= KMeans(n_clusters=i,init='k-means++',random_state=0)
    kmeans1.fit(df)
    wcss.append(kmeans1.inertia_)

# %%
wcss
# Out:
# [80.06762222222223,
#  21.139575,
#  14.630741666666667,
#  8.554825,
#  5.386700000000001,
#  3.06925,
#  1.7242499999999998,
#  0.7779999999999998,
#  0.0]

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,10),wcss)
plt.xlabel('number of clusters')
plt.ylabel('inertia')
plt.show()

# %%
kmeans= KMeans(n_clusters=2,init='k-means++',random_state=0)
y_kmeans= kmeans.fit_predict(df)
y_kmeans
# Out:
# array([0, 0, 0, 0, 0, 1, 1, 1, 1], dtype=int32)

# %%
df['clusters']= y_kmeans
df
# Out:
#    1.42  0.67  clusters
# 0  2.05  1.70         0
# 1  3.20  3.52         0
# 2  3.70  0.15         0
# 3  4.70  1.45         0
# 4  6.17  2.67         0
# 5  7.80  3.70         1
# 6  8.74  4.52         1
# 7  9.25  2.15         1
# 8  9.70  3.45         1

# %% [markdown]
# **Hierarchical clustering**

# %% [markdown]
# Also known as hierarchical cluster analysis,is an unsupervised cluster algorithm that can be catergorized in two ways:they can be agglomerative or divisive.agglomerative clustering consider a "bottom up approach" its data points are isolated as seperating grouping initialy .and then they are merged together iteratively on the basis of the similaries until one cluster has been achived. four different methods are commenly used to measure similarity.
#
# divisive clustering can be defined as oppositive of agglomerative clustering. instead it takes a "top dowm" approch. in this case a single data cluster is divided based on the difference b/w data points. divisive clustering notcommenly used . but it still worth nothing in the contex of herarchical clustering . these clustering processes are usually visualized a dendrogram, a tree like diagram.

# %% [markdown]
# **Probablitic Clustering**

# %% [markdown]
# A probabilistic model is a n unsupervised technique that helps the solve the density estimation or 'soft" clustering problems. data points are clustered based on the like hood that they belongs to a particular distribution.
#
# 1.Guassian mixture model
#
#
# GMM are classified as mixture models, which means that they are made up of an unspecified number pf probability distribution function.

# %% [markdown]
# **Assosiative Rules**

# %% [markdown]
# An assosiative rules is an rule based method for finding relationship b/w varaible in given data set.these method are frequently usedfor markectbasket analysis, allowing companies to betterunderstand relationship b/w different products.

# %% [markdown]
# **Demensionly reduction**

# %% [markdown]
# While more data generally yields more accurative results. it can also impact the performance of machine learning algorithms and it can also make it difficult to visualize datasets. Dimentionality reduction is a technique used when the number of features, or dimensions. in given datasets is too high. it reduce the number o fthe data inputs to managenarable size while also preserving the intergrity of the datasets as much as possible, it commenly used peprocessing data stage

# %% [markdown]
# **Principal component analysis**

# %% [markdown]
# PCA is atype of dimensionality reduction algorithm which is usde to compress datasets through feature extraction
