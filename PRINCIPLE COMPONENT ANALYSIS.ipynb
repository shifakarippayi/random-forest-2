# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/IRIS dataset.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x = df.drop(['species'],axis=1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xtrain=pca.fit_transform(xtrain)
xtest=pca.fit_transform(xtest)

# %%
xtrain
# Out:
# array([[ 1.27228206e+00,  3.57878727e-01],
#        [ 1.52231770e-01, -2.99835283e-01],
#        [-2.18764183e+00,  6.17154256e-01],
#        [ 9.41913396e-01,  1.21810481e-02],
#        [ 1.76227837e+00, -2.71066387e-01],
#        [-8.16806401e-02, -1.04319475e+00],
#        [-1.89794863e+00,  1.48464927e+00],
#        [ 9.59395493e-01, -6.91087802e-01],
#        [ 3.65661204e-01, -9.13013087e-02],
#        [ 2.31845912e-01, -1.01891237e+00],
#        [ 1.79730127e+00,  3.25092688e-01],
#        [-2.40350676e+00, -2.44874760e-01],
#        [ 1.82199968e+00,  5.93295049e-01],
#        [-1.98427118e+00,  5.55515137e-01],
#        [-2.17073306e+00,  1.13527621e+00],
#        [-2.55598076e-01, -2.67039928e+00],
#        [ 1.38862320e+00,  1.82768524e-01],
#        [ 1.93409268e+00,  9.57133382e-01],
#        [ 1.12243099e+00, -1.78242941e+00],
#        [ 1.88169499e+00, -8.17365689e-01],
#        [ 5.43123767e-02, -1.32586239e+00],
#        [ 2.70365641e+00,  7.16489102e-01],
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([0.76134513, 0.17546402])

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)

# %%
ypred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,ypred)
score
# Out:
# 0.7333333333333333

# %%
sepal_length = float(input('enter sepallength'))
sepal_width = float(input('enter sepalwidth'))
petal_length = float(input('enter petallength'))
petal_width = float(input('enter petalwidth'))
# Out:
# enter sepallength8
# enter sepalwidth7
# enter petallength2
# enter petalwidth1.34

# %%
model.predict(pca.transform([[sepal_length,sepal_width,petal_length,petal_width]]))
# Out:
# array(['Iris-virginica'], dtype=object)
